# %%
import os, sys
from importlib import reload

# %%
from glom_io_transform.data import odours; reload(odours)  # force reload to pick up changes in odours.py
from glom_io_transform.data import responses; reload(responses)
# Out:
# <module 'glom_io_transform.data.responses' from '/nemo/lab/schaefera/working/tootoos/git/glom-io-transform-release/glom_io_transform/data/responses.py'>

# %%
! pip install mat73
# Out:
# ...
#   Using cached h5py-3.16.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# ...
# Using cached h5py-3.16.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.1 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [mat73]
# ...

# %%
reload(odours)
reload(responses)

od_resp = responses.get_odours()
# Out:
# 2026/08/17 11:20:01                responses     INFO: registry_file='/nemo/lab/schaefera/working/tootoos/git/glom-io-transform-release/glom_io_transform/data/registry.csv' not found, building.
# 2026/08/17 11:20:03                responses     INFO: /camp/home/tootoos/working/tootoos/data/tobias/allExp/C408_allExp.mat is MTC Tbet.
# 2026/08/17 11:20:05                responses     INFO: /camp/home/tootoos/working/tootoos/data/tobias/allExp/C414_allExp.mat is MTC Tbet.
# 2026/08/17 11:20:08                responses     INFO: /camp/home/tootoos/working/tootoos/data/tobias/allExp/C420_allExp.mat is MTC Tbet.
# 2026/08/17 11:20:10                responses     INFO: /camp/home/tootoos/working/tootoos/data/tobias/allExp/C426_allExp.mat is MTC Tbet.
# 2026/08/17 11:20:13                responses     INFO: /camp/home/tootoos/working/tootoos/data/tobias/allExp/C432_allExp.mat is MTC Tbet.
# ...

# %%
[od_resp["gl_tbet"][i] for i in responses.olo]
# Out:
# ['ethyl acetate',
#  'propyl acetate',
#  'isoamyl acetate',
#  '2-heptanone',
#  '2-hexanone',
#  '2-methyl-2-butanol',
#  '4-allylanisole',
#  '(+)-fenchone',
#  'methyl benzoate',
#  '4-phenyl-2-butanone',
#  'cyclohexanol',
#  '1,4-cineole',
#  'guaiacol',
#  'cineole',
#  'benzaldehyde',
#  '2,4-dimethyl acetophenone',
#  'eugenol',
#  'mineral oil',
#  '4-methyl acetophenone',
#  'hexanoic acid',
#  '1,2-dimethoxybenzene',
#  '1-nonanol',
#  'isobutyric acid',
#  'cis-3-hexenyl tiglate',
#  'methyl salicylate',
#  's-(+)-carvone',
#  'valeric acid',
#  'octanal',
#  'alpha-terpinene',
#  'r-(+)-limonene',
#  '2-nonanone',
#  'menthone',
#  'ethyl heptanoate',
#  'acetophenone',
#  '1-heptanol',
#  'geranyl acetate',
#  'nonanoic acid',
#  'benzyl acetate',
#  '2-methoxy-4-methylphenol',
#  '2-phenylpropionaldehyde',
#  '2-hydroxy acetophenone',
#  'ethyl caproate',
#  'methyl butyrate',
#  'methyl valerate',
#  'ethyl valerate',
#  'valeraldehyde',
#  'ethyl butyrate',
# ...

# %%
odours.odours
# Out:
# Odours(names=['nonanoic acid', '2-hydroxy acetophenone', '1-nonanol', '1-heptanol', '1,2-dimethoxybenzene', '(+)-fenchone', '2-phenylpropionaldehyde', '2-nonanone', '2-methyl-2-butanol', '2-methoxy-4-methylphenol', 'hexanoic acid', '2-heptanone', 'benzyl acetate', 'benzaldehyde', 'alpha-terpinene', 'acetophenone', '4-phenyl-2-butanone', '4-allylanisole', 'ethyl valerate', 'ethyl heptanoate', 'ethyl butyrate', 'ethyl acetate', 'cyclohexanol', 'cis-3-hexenyl tiglate', 'propyl acetate', 'isoamyl acetate', '1,4-cineole', 'guaiacol', 'eugenol', 'cineole', 'methyl valerate', 'methyl salicylate', 'methyl butyrate', 'methyl benzoate', 'geranyl acetate', 'isobutyric acid', 'ethyl caproate', 'valeraldehyde', 's-(+)-carvone', 'r-(+)-limonene', 'octanal', 'valeric acid', 'mineral oil', '2,4-dimethyl acetophenone', 'menthone', 'ethyl tiglate', '2-hexanone', '4-methyl acetophenone'], classes=['Acid', 'Ketone', 'Alcohol', 'Alcohol', 'Aromatic', 'Ketone', 'Aldehyde', 'Ketone', 'Alcohol', 'Alcohol', 
# ...

# %%
odours.odours.names
# Out:
# ['nonanoic acid',
#  '2-hydroxy acetophenone',
#  '1-nonanol',
#  '1-heptanol',
#  '1,2-dimethoxybenzene',
#  '(+)-fenchone',
#  '2-phenylpropionaldehyde',
#  '2-nonanone',
#  '2-methyl-2-butanol',
#  '2-methoxy-4-methylphenol',
#  'hexanoic acid',
#  '2-heptanone',
#  'benzyl acetate',
#  'benzaldehyde',
#  'alpha-terpinene',
#  'acetophenone',
#  '4-phenyl-2-butanone',
#  '4-allylanisole',
#  'ethyl valerate',
#  'ethyl heptanoate',
#  'ethyl butyrate',
#  'ethyl acetate',
#  'cyclohexanol',
#  'cis-3-hexenyl tiglate',
#  'propyl acetate',
#  'isoamyl acetate',
#  '1,4-cineole',
#  'guaiacol',
#  'eugenol',
#  'cineole',
#  'methyl valerate',
#  'methyl salicylate',
#  'methyl butyrate',
#  'methyl benzoate',
#  'geranyl acetate',
#  'isobutyric acid',
#  'ethyl caproate',
#  'valeraldehyde',
#  's-(+)-carvone',
#  'r-(+)-limonene',
#  'octanal',
#  'valeric acid',
#  'mineral oil',
#  '2,4-dimethyl acetophenone',
#  'menthone',
#  'ethyl tiglate',
#  '2-hexanone',
# ...

# %%
od_resp["gl_tbet"] == odours.odours.names
# Out:
# True
